# %%
# !pip install webdriver-manager==4.0.2

# %%
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# %%
# !pip install streamlit==1.43.2
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.7 MB 4.8 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.7 MB 4.2 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.7 MB 4.2 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.7 MB 4.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.7 MB 4.1 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.7 MB 3.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.7 MB 4.0 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.7 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.7 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.7 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.7 MB 3.9 MB/s eta 0:00:01
# ...

# %%
path ="//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul"

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service


driver = webdriver.Chrome()
url="https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=news"
driver.get(url)

time.sleep(3)

def click_load_more():
    try:
        load_more_button = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
        
        # Scroll to the button to ensure it's in view
        ActionChains(driver).move_to_element(load_more_button).perform()
        
        # Click the button
        load_more_button.click()

        time.sleep(3)  # Wait for the new movies to load
        return True
    except Exception as e:
        print("Error clicking 'Load More' button:", e)
        return False

while click_load_more():
    print("clicked load more button")

print("no more content to load")
# Out:
# Error clicking 'Load More' button: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span"}
#   (Session info: chrome=134.0.6998.178); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6B40B4C25+3179557]
# 	(No symbol) [0x00007FF6B3D188A0]
# 	(No symbol) [0x00007FF6B3BA91CA]
# 	(No symbol) [0x00007FF6B3BFFA67]
# 	(No symbol) [0x00007FF6B3BFFC9C]
# 	(No symbol) [0x00007FF6B3C53627]
# 	(No symbol) [0x00007FF6B3C27C6F]
# 	(No symbol) [0x00007FF6B3C502F3]
# 	(No symbol) [0x00007FF6B3C27A03]
# 	(No symbol) [0x00007FF6B3BF06D0]
# 	(No symbol) [0x00007FF6B3BF1983]
# 	GetHandleVerifier [0x00007FF6B41167CD+3579853]
# 	GetHandleVerifier [0x00007FF6B412D1D2+3672530]
# ...

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service


driver = webdriver.Chrome()
url="https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=news"
driver.get(url)

time.sleep(3)

titles=[]
ratings=[]
votes=[]
durations=[]

movie_items=driver.find_elements(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

for movie in movie_items:
    try:
        title=movie.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/div[1]/a/h3').text
        
        rating=movie.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/span/div/span/span[1]').text
        
        voting=movie.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/span/div/span/span[2]').text
        
        duration=movie.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/div[2]/span[2]').text

        titles.append(title)
        ratings.append(rating)
        votes.append(voting)
        durations.append(duration)

    except Exception as e:
        print(f"Error extracting data from a movie: {e}")
        continue

df = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votes,
    'Duration': durations
})
# Save the DataFrame to a CSV file
df.to_csv('imdb_2024_movies.csv', index=False)

driver.quit()
df
# Out:
# Error extracting data from a movie: Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=134.0.6998.178); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6B40B4C25+3179557]
# 	(No symbol) [0x00007FF6B3D188A0]
# 	(No symbol) [0x00007FF6B3BA91CA]
# 	(No symbol) [0x00007FF6B3BFFA67]
# 	(No symbol) [0x00007FF6B3BFFC9C]
# 	(No symbol) [0x00007FF6B3BF240C]
# 	(No symbol) [0x00007FF6B3C27C6F]
# 	(No symbol) [0x00007FF6B3BF22D6]
# 	(No symbol) [0x00007FF6B3C27E40]
# 	(No symbol) [0x00007FF6B3C502F3]
# 	(No symbol) [0x00007FF6B3C27A03]
# 	(No symbol) [0x00007FF6B3BF06D0]
# 	(No symbol) [0x00007FF6B3BF1983]
# 	GetHandleVerifier [0x00007FF6B41167CD+3579853]
# 	GetHandleVerifier [0x00007FF6B412D1D2+3672530]
# 	GetHandleVerifier [0x00007FF6B4122153+3627347]
# ...

# %%
#df.to_csv("action.csv")
#df.to_csv("adventure.csv")
#df.to_csv("animation.csv")
#df.to_csv("music.csv")
df.to_csv("news.csv")

# %%
#to add genre column in action.csv and fill as Action for each row
df = pd.read_csv("action.csv")
df['Genre'] = 'Action'
df.to_csv("action.csv", index=False)
df = pd.read_csv("adventure.csv") 
df['Genre'] = 'Adventure'
df.to_csv("adventure.csv", index=False)
df = pd.read_csv("animation.csv")
df['Genre'] = 'Animation'
df.to_csv("animation.csv", index=False)
df = pd.read_csv("music.csv")
df['Genre'] = 'Music'
df.to_csv("music.csv", index=False)
df = pd.read_csv("news.csv")
df['Genre'] = 'News'
df.to_csv("news.csv", index=False)

# %%
#Merge all genre-wise CSVs into a single DataFrame.
import pandas as pd

# Load the genre-wise CSV files
action = pd.read_csv('action.csv')
adventure = pd.read_csv('adventure.csv')
animation = pd.read_csv('animation.csv')
music = pd.read_csv('music.csv')
news = pd.read_csv('news.csv')

# Merge the DataFrames
all_movies = pd.concat([action, adventure, animation, music, news])
all_movies
# Out:
#      Unnamed: 0                                              Title  Rating  \
# 0             0                               1. Kraven the Hunter     5.5
# 1             1                                        2. Twisters     6.5
# 2             2                                    3. Gladiator II     6.5
# 3             3                            4. Sonic the Hedgehog 3     6.9
# 4             4                           5. Venom: The Last Dance     6.0
# ..          ...                                                ...     ...
# 212         212  426. Stay Homas. La banda que no hauria d'existir     7.0
# 0             0            1. Every Christopher Nolan Movie Ranked     8.7
# 1             1                                3. The Fall of 2008     8.4
# 2             2                   4. The Truth: The Journey Within     7.2
# 3             3  5. The Turning Point: XCLD: The Story of Cance...     5.4
#
#        Votes Duration   Genre
# 0      (50K)    2h 7m  Action
# ...

# %%
all_movies = pd.concat([action, adventure, animation, music, news])

# Save the merged DataFrame to a CSV file
all_movies.to_csv("all_movies.csv", index=False)

print("Merged DataFrame saved to 'all_movies.csv'")
# Out:
# Merged DataFrame saved to 'all_movies.csv'

# %%
#convert all_movies.csv to dataframe
df = pd.read_csv("all_movies.csv")
df
# Out:
#       Unnamed: 0                                              Title  Rating  \
# 0              0                               1. Kraven the Hunter     5.5
# 1              1                                        2. Twisters     6.5
# 2              2                                    3. Gladiator II     6.5
# 3              3                            4. Sonic the Hedgehog 3     6.9
# 4              4                           5. Venom: The Last Dance     6.0
# ...          ...                                                ...     ...
# 1620         212  426. Stay Homas. La banda que no hauria d'existir     7.0
# 1621           0            1. Every Christopher Nolan Movie Ranked     8.7
# 1622           1                                3. The Fall of 2008     8.4
# 1623           2                   4. The Truth: The Journey Within     7.2
# 1624           3  5. The Turning Point: XCLD: The Story of Cance...     5.4
#
#         Votes Duration   Genre
# ...

# %%
df["Votes"]=df["Votes"].str.replace("(","").str.replace(")","")
display(df)
# Out:
#       Unnamed: 0                                              Title  Rating  \
# 0              0                               1. Kraven the Hunter     5.5
# 1              1                                        2. Twisters     6.5
# 2              2                                    3. Gladiator II     6.5
# 3              3                            4. Sonic the Hedgehog 3     6.9
# 4              4                           5. Venom: The Last Dance     6.0
# ...          ...                                                ...     ...
# 1620         212  426. Stay Homas. La banda que no hauria d'existir     7.0
# 1621           0            1. Every Christopher Nolan Movie Ranked     8.7
# 1622           1                                3. The Fall of 2008     8.4
# 1623           2                   4. The Truth: The Journey Within     7.2
# 1624           3  5. The Turning Point: XCLD: The Story of Cance...     5.4
#
#       Votes Duration   Genre
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1625 entries, 0 to 1624
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1625 non-null   int64
#  1   Title       1625 non-null   object
#  2   Rating      1625 non-null   float64
#  3   Votes       1625 non-null   object
#  4   Duration    1625 non-null   object
#  5   Genre       1625 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 76.3+ KB

# %%
#Voting Counts: Filter based on the number of votes received (e.g., > 10,000 votes).
# Ensure the 'Votes' column is treated as a string before replacing commas
df["Votes"] = df["Votes"].astype(str).str.replace(",", "", regex=True)

# Convert the cleaned 'Votes' column to numeric, setting invalid values to NaN
df["Votes"] = pd.to_numeric(df["Votes"], errors="coerce")

# Drop rows with NaN values in the 'Votes' column
df = df.dropna(subset=["Votes"])

# Convert 'Votes' to integers
df["Votes"] = df["Votes"].astype(int)

display(df)
# Out:
# C:\Users\jesin\AppData\Local\Temp\ipykernel_20956\494845046.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Votes"] = df["Votes"].astype(int)
#       Unnamed: 0                                              Title  Rating  \
# 32            32                                   33. Freaky Tales     6.4
# 44            44                                  45. Baby Invasion     4.7
# 80            80                                         81. Hitpig     5.1
# 81            81                                     82. Dark Match     5.5
# 88            88                                           89. Raqa     5.7
# ...          ...                                                ...     ...
# ...

# %%
# Print the original 'Duration' column for debugging
print("Original 'Duration' column:")
print(df["Duration"])
# Out:
# Original 'Duration' column:
# 32      1h 46m
# 44      1h 20m
# 80      1h 26m
# 81      1h 34m
# 88      1h 47m
#          ...
# 1620    1h 22m
# 1621       59m
# 1622     1h 1m
# 1623    1h 31m
# 1624       44m
# Name: Duration, Length: 1153, dtype: object

# %%
import pandas as pd
import numpy as np
import re

# Function to convert '1h 46m' format to total minutes
def convert_to_minutes(duration):
    hours = 0
    minutes = 0
    if 'h' in duration:
        hours = int(duration.split('h')[0].strip())
        duration = duration.split('h')[1].strip()  # Remove the hours part
    if 'm' in duration:
        minutes = int(duration.replace('m', '').strip())
    return hours * 60 + minutes


# Apply the function to the 'Duration' column
df['Duration'] = df['Duration'].apply(convert_to_minutes)

# Display the updated DataFrame
print(df)
# Out:
#       Unnamed: 0                                              Title  Rating  \
# 32            32                                   33. Freaky Tales     6.4
# 44            44                                  45. Baby Invasion     4.7
# 80            80                                         81. Hitpig     5.1
# 81            81                                     82. Dark Match     5.5
# 88            88                                           89. Raqa     5.7
# ...          ...                                                ...     ...
# 1620         212  426. Stay Homas. La banda que no hauria d'existir     7.0
# 1621           0            1. Every Christopher Nolan Movie Ranked     8.7
# 1622           1                                3. The Fall of 2008     8.4
# 1623           2                   4. The Truth: The Journey Within     7.2
# 1624           3  5. The Turning Point: XCLD: The Story of Cance...     5.4
#
#       Votes  Duration   Genre
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1153 entries, 32 to 1624
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1153 non-null   int64
#  1   Title       1153 non-null   object
#  2   Rating      1153 non-null   float64
#  3   Votes       1153 non-null   int64
#  4   Duration    1153 non-null   int64
#  5   Genre       1153 non-null   object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 63.1+ KB

# %%
#convert this dataframe to csv
df.to_csv("all_movies.csv", index=False)

# %%
#drop the unnamed: 0 column
df = pd.read_csv("all_movies.csv")
df = df.drop(columns=["Unnamed: 0"])
df.to_csv("all_movies.csv", index=False)

# %%
#convert this csv to dataframe
df = pd.read_csv("all_movies.csv")
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1153 entries, 0 to 1152
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     1153 non-null   object
#  1   Rating    1153 non-null   float64
#  2   Votes     1153 non-null   int64
#  3   Duration  1153 non-null   int64
#  4   Genre     1153 non-null   object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 45.2+ KB
#                                                   Title  Rating  Votes  \
# 0                                      33. Freaky Tales     6.4    418
# 1                                     45. Baby Invasion     4.7    354
# 2                                            81. Hitpig     5.1    888
# 3                                        82. Dark Match     5.5    902
# 4                                              89. Raqa     5.7    160
# ...                                                 ...     ...    ...
# ...

# %%
#dataframe to sql
import sqlite3
import pandas as pd 
import os

# Create a connection to the SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect('DB\movies.db')

# Create a cursor object to execute SQL commands
cursor = conn.cursor()

df = pd.read_csv("all_movies.csv")  

# Insert the DataFrame into the SQLite table
df.to_sql('movies', conn, if_exists='replace', index=False)
# Commit the changes    
conn.commit()
# Close the connection
conn.close()
# Check if the database file exists
if os.path.exists('movies.db'):
    print("Database file created successfully.")
else:
    print("Failed to create the database file.")
# Read the data back from the SQLite database to verify
conn = sqlite3.connect('movies.db')
df = pd.read_sql_query("SELECT * FROM movies", conn)
print(df.head())  # Display the first few rows of the DataFrame
conn.close()
# Out:
# Database file created successfully.
#                Title  Rating  Votes  Duration   Genre
# 0   33. Freaky Tales     6.4    418       106  Action
# 1  45. Baby Invasion     4.7    354        80  Action
# 2         81. Hitpig     5.1    888        86  Action
# 3     82. Dark Match     5.5    902        94  Action
# 4           89. Raqa     5.7    160       107  Action
